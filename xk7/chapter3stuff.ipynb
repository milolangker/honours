# %%
from scipy.special import j1
import numpy as np
import matplotlib.pyplot as plt

((j1(10*np.pi)/(10*np.pi))**2 / (j1(0.000001)/0.000001)**2)*100
# Out:
# np.float64(0.004009934222958212)

# %%
j1(0.001)/0.001
# Out:
# np.float64(0.49999993750000266)

# %%
x=np.linspace(0.01, 10*np.pi, 1000)

plt.plot(x, 4*(j1(x)/x)**2)
plt.yscale('log')
plt.show()
